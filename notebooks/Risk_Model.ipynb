# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/TIRUPATHI/Downloads/my projects/credit card risk factor/statlog+german+credit+data/german.data")
df.head()
# Out:
#   A11 6 A34 A43 1169 A65 A75 4 A93 A101 4 A121 67 A143 A152 2 A173 1 A192 A201 1
# 0  A12 48 A32 A43 5951 A61 A73 2 A92 A101 2 A121 ...
# 1  A14 12 A34 A46 2096 A61 A74 2 A93 A101 3 A121 ...
# 2  A11 42 A32 A42 7882 A61 A74 2 A93 A103 4 A122 ...
# 3  A11 24 A33 A40 4870 A61 A73 3 A93 A101 4 A124 ...
# 4  A14 36 A32 A46 9055 A65 A73 2 A93 A101 4 A124 ...

# %%
columns = [
    "CheckingAccountStatus","Duration","CreditHistory","Purpose",
    "CreditAmount","Savings","Employment","InstallmentRate",
    "PersonalStatusSex","Guarantors","ResidenceSince","Property",
    "Age","OtherInstallmentPlans","Housing","ExistingCredits",
    "Job","Dependents","Telephone","ForeignWorker","CreditRisk"
]

df = pd.read_csv("C:/Users/TIRUPATHI/Downloads/my projects/credit card risk factor/statlog+german+credit+data/german.data", 
                 sep=" ",
                 header=None, 
                 names=columns)
df.head()
# Out:
#   CheckingAccountStatus  Duration CreditHistory Purpose  CreditAmount Savings  \
# 0                   A11         6           A34     A43          1169     A65
# 1                   A12        48           A32     A43          5951     A61
# 2                   A14        12           A34     A46          2096     A61
# 3                   A11        42           A32     A42          7882     A61
# 4                   A11        24           A33     A40          4870     A61
#
#   Employment  InstallmentRate PersonalStatusSex Guarantors  ...  Property Age  \
# 0        A75                4               A93       A101  ...      A121  67
# 1        A73                2               A92       A101  ...      A121  22
# 2        A74                2               A93       A101  ...      A121  49
# 3        A74                2               A93       A103  ...      A122  45
# 4        A73                3               A93       A101  ...      A124  53
#
# ...

# %%
df["CreditRisk"] = df["CreditRisk"].map({1: 0, 2: 1})
df.head()
# Out:
#   CheckingAccountStatus  Duration CreditHistory Purpose  CreditAmount Savings  \
# 0                   A11         6           A34     A43          1169     A65
# 1                   A12        48           A32     A43          5951     A61
# 2                   A14        12           A34     A46          2096     A61
# 3                   A11        42           A32     A42          7882     A61
# 4                   A11        24           A33     A40          4870     A61
#
#   Employment  InstallmentRate PersonalStatusSex Guarantors  ...  Property Age  \
# 0        A75                4               A93       A101  ...      A121  67
# 1        A73                2               A92       A101  ...      A121  22
# 2        A74                2               A93       A101  ...      A121  49
# 3        A74                2               A93       A103  ...      A122  45
# 4        A73                3               A93       A101  ...      A124  53
#
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CheckingAccountStatus  1000 non-null   object
#  1   Duration               1000 non-null   int64
#  2   CreditHistory          1000 non-null   object
#  3   Purpose                1000 non-null   object
#  4   CreditAmount           1000 non-null   int64
#  5   Savings                1000 non-null   object
#  6   Employment             1000 non-null   object
#  7   InstallmentRate        1000 non-null   int64
#  8   PersonalStatusSex      1000 non-null   object
#  9   Guarantors             1000 non-null   object
#  10  ResidenceSince         1000 non-null   int64
#  11  Property               1000 non-null   object
#  12  Age                    1000 non-null   int64
#  13  OtherInstallmentPlans  1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# CheckingAccountStatus    0
# Duration                 0
# CreditHistory            0
# Purpose                  0
# CreditAmount             0
# Savings                  0
# Employment               0
# InstallmentRate          0
# PersonalStatusSex        0
# Guarantors               0
# ResidenceSince           0
# Property                 0
# Age                      0
# OtherInstallmentPlans    0
# Housing                  0
# ExistingCredits          0
# Job                      0
# Dependents               0
# Telephone                0
# ForeignWorker            0
# CreditRisk               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#           Duration  CreditAmount  InstallmentRate  ResidenceSince  \
# count  1000.000000   1000.000000      1000.000000     1000.000000
# mean     20.903000   3271.258000         2.973000        2.845000
# std      12.058814   2822.736876         1.118715        1.103718
# min       4.000000    250.000000         1.000000        1.000000
# 25%      12.000000   1365.500000         2.000000        2.000000
# 50%      18.000000   2319.500000         3.000000        3.000000
# 75%      24.000000   3972.250000         4.000000        4.000000
# max      72.000000  18424.000000         4.000000        4.000000
#
#                Age  ExistingCredits   Dependents   CreditRisk
# count  1000.000000      1000.000000  1000.000000  1000.000000
# mean     35.546000         1.407000     1.155000     0.300000
# std      11.375469         0.577654     0.362086     0.458487
# min      19.000000         1.000000     1.000000     0.000000
# ...

# %%
cat_cols = df.select_dtypes(include='object').columns
num_cols = df.select_dtypes(include='int64').drop("CreditRisk", axis=1).columns

# %%
print(cat_cols)
# Out:
# Index(['CheckingAccountStatus', 'CreditHistory', 'Purpose', 'Savings',
#        'Employment', 'PersonalStatusSex', 'Guarantors', 'Property',
#        'OtherInstallmentPlans', 'Housing', 'Job', 'Telephone',
#        'ForeignWorker'],
#       dtype='object')

# %%
print(num_cols)
# Out:
# Index(['Duration', 'CreditAmount', 'InstallmentRate', 'ResidenceSince', 'Age',
#        'ExistingCredits', 'Dependents'],
#       dtype='object')

# %%
df["CreditRisk"].value_counts(normalize=True).plot(kind="bar")
plt.title("Credit Risk Distribution")
plt.show()

# %%
for col in ["CreditAmount","Duration","Age"]:
    df[col].hist(bins=30)
    plt.title(col)
    plt.show()

# %%
df.groupby("CreditRisk")["CreditAmount"].mean()
# Out:
# CreditRisk
# 0    2985.457143
# 1    3938.126667
# Name: CreditAmount, dtype: float64

# %%
df.groupby("CreditRisk")["Duration"].mean()
# Out:
# CreditRisk
# 0    19.207143
# 1    24.860000
# Name: Duration, dtype: float64

# %%
df.groupby("CreditRisk")["Age"].mean()
# Out:
# CreditRisk
# 0    36.224286
# 1    33.963333
# Name: Age, dtype: float64

# %%
df.groupby("CreditRisk")["Employment"].value_counts(normalize=True)
# Out:
# CreditRisk  Employment
# 0           A73           0.335714
#             A75           0.270000
#             A74           0.192857
#             A72           0.145714
#             A71           0.055714
# 1           A73           0.346667
#             A72           0.233333
#             A75           0.213333
#             A74           0.130000
#             A71           0.076667
# Name: proportion, dtype: float64

# %%
import seaborn as sns

sns.heatmap(df[num_cols].corr(), cmap="coolwarm")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in cat_cols:
    df[col] = le.fit_transform(df[col])

# %%
X = df.drop("CreditRisk", axis=1)
y = df["CreditRisk"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, lr.predict(X_test))
accuracy_score(y_test, rf.predict(X_test))
# Out:
# 0.7766666666666666

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, lr.predict(X_test))
# Out:
# array([[183,  27],
#        [ 46,  44]])

# %%
from sklearn.metrics import roc_auc_score, roc_curve
lr_probs = lr.predict_proba(X_test)[:,1]
roc_auc_score(y_test, lr_probs)
# Out:
# 0.7768783068783068

# %%
fpr, tpr, _ = roc_curve(y_test, lr_probs)
plt.plot(fpr, tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.show()

# %%
feat_importances = pd.Series(rf.feature_importances_, index=X.columns)
feat_importances.sort_values().plot(kind='barh')
plt.title('Feature Importance')
plt.show()
